# %%
import pandas as pd

df1 = pd.read_csv('datasets/KV-SingleApp-PeriodicLoad/X_cluster.csv')
df2 = pd.read_csv('datasets/KV-SingleApp-PeriodicLoad/Y.csv')

# %%
#df1['TimeStamp'] = pd.to_datetime(df1['TimeStamp'])
#df2['TimeStamp'] = pd.to_datetime(df2['TimeStamp'])

df = df1.merge(df2, on='TimeStamp', how='inner')

# %%
df.head(5)
# Out:
#                       TimeStamp  0_all_..usr  0_all_..nice  0_all_..sys  \
# 0 1970-01-01 00:00:01.479626031         2.23             0         0.55
# 1 1970-01-01 00:00:01.479626038         3.48             0         0.76
# 2 1970-01-01 00:00:01.479626041         5.40             0         0.79
# 3 1970-01-01 00:00:01.479626042         3.35             0         0.75
# 4 1970-01-01 00:00:01.479626043         3.19             0         0.71
#
#    0_all_..iowait  0_all_..steal  0_all_..irq  0_all_..soft  0_all_..guest  \
# 0            0.42              0          0.0          0.08              0
# 1            1.51              0          0.0          0.13              0
# 2            5.36              0          0.0          0.17              0
# 3            2.76              0          0.0          0.17              0
# 4            5.71              0          0.0          0.21              0
#
#    0_all_..gnice  ...  5_X.dev.mapper.cloud..5.root_.Iused  \
# 0              0  ...                                 1.24
# 1              0  ...                                 1.24
# 2              0  ...                                 1.24
# 3              0  ...                                 1.24
# 4              0  ...                                 1.24
#
#    5_X.dev.sda1_MBfsfree  5_X.dev.sda1_MBfsused  5_X.dev.sda1_.fsused  \
# 0                    139                     89                 38.94
# 1                    139                     89                 38.94
# 2                    139                     89                 38.94
# 3                    139                     89                 38.94
# 4                    139                     89                 38.94
#
#    5_X.dev.sda1_.ufsused  5_X.dev.sda1_Ifree  5_X.dev.sda1_Iused  \
# 0                  44.28              124184                 312
# 1                  44.28              124184                 312
# 2                  44.28              124184                 312
# 3                  44.28              124184                 312
# 4                  44.28              124184                 312
#
#    5_X.dev.sda1_.Iused  ReadsAvg  WritesAvg
# 0                 0.25   73.8254   175.5445
# 1                 0.25   56.2413   115.2276
# 2                 0.25   56.8517   120.2875
# 3                 0.25   56.9347   108.4472
# 4                 0.25   60.5642   108.4257
#
# [5 rows x 10377 columns]
